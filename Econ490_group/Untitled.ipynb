# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('C:/Users/hubst/Downloads')

# %%
acs = pd.read_csv('usa_00003.csv')
acs
# Out:
#           YEAR  SAMPLE   SERIAL       CBSERIAL  HHWT        CLUSTER  REGION  \
# 0         2010  201001        1             69  96.0  2010000000011      32
# 1         2010  201001        2             80  97.0  2010000000021      32
# 2         2010  201001        2             80  97.0  2010000000021      32
# 3         2010  201001        2             80  97.0  2010000000021      32
# 4         2010  201001        3            140  90.0  2010000000031      32
# ...        ...     ...      ...            ...   ...            ...     ...
# 31499763  2019  201901  1428035  2019001411842  29.0  2019014280351      41
# 31499764  2019  201901  1428035  2019001411842  29.0  2019014280351      41
# 31499765  2019  201901  1428036  2019001412021  51.0  2019014280361      41
# 31499766  2019  201901  1428037  2019001412362  65.0  2019014280371      41
# 31499767  2019  201901  1428037  2019001412362  65.0  2019014280371      41
#
# ...

# %%
acs = acs.drop(columns = ['GQ','CITYPOP','LOOKING','AVAILBLE','HHWT','CBSERIAL','SAMPLE'])
acs = acs[acs['YEAR'] >= 2012]
acs = acs[acs['YEAR'] <= 2016]
acs = acs[acs['AGE'] >= 16]
acs = acs[acs['AGE'] <= 65]

# %%
mich = acs[acs['STATEFIP'] == 26]
wisc = acs[acs['STATEFIP'] == 55]

# %%
print(mich)
print(wisc)
# Out:
#           YEAR  SERIAL        CLUSTER  REGION  STATEFIP  COUNTYFIP  DENSITY  \
# 7593707   2012  615216  2012006152161      21        26        125   2899.0
# 7593708   2012  615217  2012006152171      21        26        115    476.4
# 7593709   2012  615217  2012006152171      21        26        115    476.4
# 7593714   2012  615219  2012006152191      21        26        145    684.7
# 7593715   2012  615219  2012006152191      21        26        145    684.7
# ...        ...     ...            ...     ...       ...        ...      ...
# 20239257  2016  669725  2016006697251      21        26          0   3701.5
# 20239258  2016  669726  2016006697261      21        26        163   6877.2
# 20239259  2016  669726  2016006697261      21        26        163   6877.2
# 20239260  2016  669726  2016006697261      21        26        163   6877.2
# 20239261  2016  669726  2016006697261      21        26        163   6877.2
#
# ...

# %%
print(mich['AGE'].describe())
print(wisc['AGE'].describe())
# Out:
# count    318060.000000
# mean         42.233560
# std          14.802939
# min          16.000000
# 25%          29.000000
# 50%          44.000000
# 75%          55.000000
# max          65.000000
# Name: AGE, dtype: float64
# count    188066.000000
# mean         42.629316
# std          14.682713
# min          16.000000
# 25%          30.000000
# 50%          45.000000
# 75%          55.000000
# max          65.000000
# Name: AGE, dtype: float64
